# %%
print("hello world ")
# Out:
# hello world

# %%
import gensim.downloader as api

model = api.load("glove-wiki-gigaword-50")

# %%
print(api.BASE_DIR)
# Out:
# /home/manh/gensim-data

# %%
print(f"vector size {model.vector_size}")
# Out:
# vector size 50
